# %% [markdown]
# # Задание 1
# Даны 2 переменных, в которых хранятся строки произвольной длины: phrase_1 и phrase_2.
# Напишите код, который проверяет какая из этих строк длиннее.
#
# Примеры работы программы:
# 1.
# phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики'
# phrase_2 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
#
# Результат:
# Фраза 1 длиннее фразы 2
#
# 1.
# phrase_1 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
# phrase_2 = 'Насколько проще было бы писать программы, если бы не заказчики'
#
# Результат:
# Фраза 2 длиннее фразы 1
#
# 1.
# phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики'
# phrase_2 = 'Насколько проще было бы писать программы, если бы не заказчики'
#
# Результат:
# Фразы равной длины

# %%
phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики' 
phrase_2 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

if len(phrase_1) > len(phrase_2):
    print('Результат: Фраза 1 длиннее фразы 2')
elif len(phrase_1) < len(phrase_2):
    print('Результат: Фраза 2 длиннее фразы 1')
else:
    print('Результат: Фразы равной длины')
# Out:
# Результат: Фраза 1 длиннее фразы 2

# %% [markdown]
# # Задание 2
# Дана переменная, в которой хранится четырехзначное число (год). Необходимо написать программу, которая выведет, является ли данный год високосным или обычным.
#
# Пример работы программы:
# 1.
# year = 2020
# Результат:
# Високосный год
#
# 1.
# year = 2019
# Результат:
# Обычный год
#
# Подсказка:
# Високосный год кратен 4, но при этом не кратен 100, либо кратен 400. Иными словами, если год делится на 4 без остатка, но делится на 100 только с остатком, то он високосный, иначе — невисокосный, кроме случая, если он делится без остатка на 400 — тогда он всё равно високосный.

# %%
year = 2019
if year % 4 == 0 and year % 100 != 0:
    print (year, '- Високосный год')
elif year % 400 == 0:
    print (year, '- Високосный год')
else:
    print (year, '- Обычный год')
# Out:
# 2019 - Обычный год

# %% [markdown]
# ## Задание 3
# Необходимо написать программу, которая будет запрашивать у пользователя месяц и дату рождения и выводить соответствующий знак зодиака.
#
# Пример работы программы:
# 1.
# Введите день:
# 30
#
# Введите месяц:
# Август
#
# Результат:
# Ваш знак зодиака: Дева
#
# 1.
# Введите день:
# 29
#
# Введите месяц:
# Октябрь
#
# Результат:
# Ваш знак зодиака: Скорпион
#
# Справочно:
# Овен (21 марта — 20 апреля)
# Телец (21 апреля — 21 мая)
# Близнецы (22 мая — 21 июня)
# Рак (22 июня — 22 июля)
# Лев (23 июля — 21 августа)
# Дева (22 августа — 23 сентября)
# Весы (24 сентября — 23 октября)
# Скорпион (24 октября — 22 ноября)
# Стрелец (23 ноября — 22 декабря)
# Козерог (23 декабря — 20 января)
# Водолей (21 января — 19 февраля)
# Рыбы (20 февраля — 20 марта)

# %% [markdown]
# Вариант решения №1

# %%
date = int(input('Введите день рождения:'))
month = input('Введите месяц рождения:')

if (((date >= 21 and date <= 31) and (month == 'Март' or month == '3')) or
    ((date >= 1 and date <= 20) and (month == 'Апрель' or month == '4'))):
    print ('Ваш знак зодиака: Овен')
elif (((date >= 21 and date <= 30) and (month == 'Апрель' or month == '4')) or
    ((date >= 1 and date <= 21) and (month == 'Май' or month == '5'))):
    print ('Ваш знак зодиака: Телец')
elif (((date >= 22 and date <= 31) and (month == 'Май' or month == '5')) or
    ((date >= 1 and date <= 21) and (month == 'Июнь' or month == '6'))):
    print ('Ваш знак зодиака: Близнецы')
elif (((date >= 22 and date <= 30) and (month == 'Июнь' or month == '6')) or
    ((date >= 1 and date <= 22) and (month == 'Июль' or month == '7'))):
    print ('Ваш знак зодиака: Рак')
elif (((date >= 23 and date <= 31) and (month == 'Июль' or month == '7')) or
    ((date >= 1 and date <= 21) and (month == 'Август' or month == '8'))):
    print ('Ваш знак зодиака: Лев')
elif (((date >= 22 and date <= 31) and (month == 'Август' or month == '8')) or
    ((date >= 1 and date <= 23) and (month == 'Сентябрь' or month == '9'))):
    print ('Ваш знак зодиака: Дева')
elif (((date >= 24 and date <= 30) and (month == 'Сентябрь' or month == '9')) or
    ((date >= 1 and date <= 23) and (month == 'Октябрь' or month == '10'))):
    print ('Ваш знак зодиака: Весы')
elif (((date >= 24 and date <= 31) and (month == 'Октябрь' or month == '10')) or
    ((date >= 1 and date <= 22) and (month == 'Ноябрь' or month == '11'))):
    print ('Ваш знак зодиака: Скорпион')
elif (((date >= 23 and date <= 30) and (month == 'Ноябрь' or month == '11')) or
    ((date >= 1 and date <= 22) and (month == 'Декабрь' or month == '12'))):
    print ('Ваш знак зодиака: Стрелец')
elif (((date >= 23 and date <= 31) and (month == 'Декабрь' or month == '12')) or
    ((date >= 1 and date <= 20) and (month == 'Январь' or month == '1'))):
    print ('Ваш знак зодиака: Козерог')
elif (((date >= 21 and date <= 31) and (month == 'Январь' or month == '1')) or
    ((date >= 1 and date <= 19) and (month == 'Февраль' or month == '2'))):
    print ('Ваш знак зодиака: Водолей')
elif (((date >= 20 and date <= 29) and (month == 'Февраль' or month == '2')) or
    ((date >= 1 and date <= 20) and (month == 'Март' or month == '3'))):
    print ('Ваш знак зодиака: Рыбы')
# Out:
# Введите день рождения:7
# Введите месяц рождения:Апрель
# Ваш знак зодиака: Овен

# %% [markdown]
# Вариант решения №2

# %%
date = int(input('Введите день рождения:'))
month = input('Введите месяц рождения:')

if (month == 'Март' or month == '3'):
    print ('Ваш знак зодиака: Рыбы') if (date < 21) else print ('Ваш знак зодиака: Овен')
elif (month == 'Апрель' or month == '4'):
    print ('Ваш знак зодиака: Овен') if (date < 21) else print ('Ваш знак зодиака: Телец')
elif (month == 'Май' or month == '5'):
    print ('Ваш знак зодиака: Телец') if (date < 21) else print ('Ваш знак зодиака: Близнецы')
elif (month == 'Июнь' or month == '6'):
    print ('Ваш знак зодиака: Близнецы') if (date < 21) else print ('Ваш знак зодиака: Рак')
elif (month == 'Июль' or month == '7'):
    print ('Ваш знак зодиака: Рак') if (date < 21) else print ('Ваш знак зодиака: Лев')
elif (month == 'Август' or month == '8'):
    print ('Ваш знак зодиака: Лев') if (date < 21) else print ('Ваш знак зодиака: Дева')
elif (month == 'Сентябрь' or month == '9'):
    print ('Ваш знак зодиака: Дева') if (date < 21) else print ('Ваш знак зодиака: Весы')
elif (month == 'Октябрь' or month == '10'):
    print ('Ваш знак зодиака: Весы') if (date < 21) else print ('Ваш знак зодиака: Скорпион')
elif (month == 'Ноябрь' or month == '11'):
    print ('Ваш знак зодиака: Скорпион') if (date < 21) else print ('Ваш знак зодиака: Стрелец')
elif (month == 'Декабрь' or month == '12'):
    print ('Ваш знак зодиака: Стрелец') if (date < 21) else print ('Ваш знак зодиака: Козерог')
elif (month == 'Январь' or month == '1'):
    print ('Ваш знак зодиака: Козерог') if (date < 21) else print ('Ваш знак зодиака: Водолей')
elif (month == 'Февраль' or month == '2'):
    print ('Ваш знак зодиака: Водолей') if (date < 21) else print ('Ваш знак зодиака: Рыбы')
# Out:
# Введите день рождения:27
# Введите месяц рождения:Январь
# Ваш знак зодиака: Водолей

# %% [markdown]
# ## Задание 4
# Вам нужно написать программу для подбора упаковок по размерам товара. Размеры (ширина, длина, высота) хранятся в переменных (в сантиметрах):
#
# Используйте следующие правила:
#
# - если каждое из трех измерений менее 15 сантиметров, то выведите на экран "Коробка №1";
# - если хотя бы одно из измерений больше 15 сантиметров, но менее 50 сантиметров, то выводите "Коробка №2";
# - если длина товара больше 2 метров, то выводите "Упаковка для лыж";
# - во всех остальных случаях выводите "Стандартная коробка №3".
#
# Пример работы программы:
# 1.
# - width = 15
# - length = 50
# - height = 15
#
# Результат:  Стандартная коробка №3
#
# 1.
# - width = 45
# - length = 205
# - height = 45
#
# Результат: Ищите упаковку для лыж

# %%
width = int(input('Ширина, см: '))
length = int(input('Длина, см: '))
height = int(input('Высота, см: '))

if length > 200:
    print('Упаковка для лыж')
elif width < 15 and length < 15 and height < 15:
    print('Коробка №1')
elif (width > 15 and width < 50) or (length > 15 and length < 50) or (height > 15 and height < 50):
    print('Коробка №2')
else:
    print('Стандартная коробка №3')
# Out:
# Ширина, см: 15
# Длина, см: 15
# Высота, см: 15
# Коробка №2

# %% [markdown]
# ## Задание 5 (необязательное)
# Дана переменная, в которой хранится шестизначное число (номер проездного билета). Напишите программу, которая будет определять, является ли данный билет "счастливым". Билет считается счастливым, если сумма первых трех цифр совпадает с суммой последних трех цифр номера.
#
# Примеры работы программы:
# 1. number = 123456
#
# Результат: Несчастливый билет
#
# 1. number = 123321
#
# Результат: Счастливый билет

# %%
number = int(input('6-ти значный номер билета: '))
b = number//1000

one = b // 100
two = b // 10 % 10    
three = b % 10

c = number % 1000

four = c // 100
five = c // 10 % 10
six = c % 10

if (one+two+three)==(four+five+six):
    print ('Счастливый билет')
else:
    print ('Несчастливый билет')
# Out:
# 6-ти значный номер билета: 123231
# Счастливый билет

# %% [markdown]
# ## Задание 6 (необязательное)
# Напишите программу, которая сможет вычислять площади трех фигур (круг, треугольник и прямоугольник). Тип фигуры запрашиваем через пользовательский ввод, после чего делаем запрос характеристик фигуры:
# - если пользователь выбрал круг, запрашиваем его радиус,
# - если треугольник – длины трех его сторон;
# - если прямоугольник – длины двух его сторон.
#
# Пример работы программы:
# 1.
# Введите тип фигуры: Круг
#
# Введите радиус круга: 10
#
# Результат: Площадь круга: 314.16
#
# 2.
# Введите тип фигуры: Треугольник
#
# Введите длину стороны A: 2
#
# Введите длину стороны B: 2
#
# Введите длину стороны C: 3
#
# Результат: Площадь треугольника: 1.98
#
# Справочно:
# - Площадь круга:  S = π * r^2
# - Площадь треугольника: S=√p(p−a)(p−b)(p−c), где р = (a+b+c)/2
# - Площадь прямоугольника: S=a*b

# %%
figure = input('Введите тип фигуры: ')

if figure =='Круг': 
    R = float(input('Введите радиус круга: ')) 
    S = 3.14*(R**2)
elif figure =='Прямоугольник':
    a = float(input('Введите сторону a прямоугольника: '))
    b = float(input('Введите сторону b прямоугольника: '))
    S = a*b
elif figure =='Треугольник':
    a = float(input('Введите сторону a прямоугольника: '))
    b = float(input('Введите сторону b прямоугольника: '))
    c = float(input('Введите сторону c прямоугольника: '))
    p = (a+b+c)/2
    S = (p*(p-a)*(p-b)*(p-c))**0.5
print ('Площадь ', figure, ': ', round(S,3), 'кв.см')
# Out:
# Введите тип фигуры: Треугольник
# Введите сторону a прямоугольника: 3
# Введите сторону b прямоугольника: 5
# Введите сторону c прямоугольника: 6
# Площадь  Треугольник :  7.483 кв.см
